# %%
import numpy as np
import scipy as sc
import operators.plaqOps as plaq_states

# %%
def H(nx,ny,g2):
    oL, Lsq, ImTrP = plaq_states._getPlaqStateOps(0.5, g2)

    dim = 2**(nx*ny)
    x = []
    y = []
    data = []

    x = x+list(np.arange(dim))
    y = y+list(np.arange(dim))
    data = data+[]

    return sc.sparse.coo_matrix((data,x,y))

# %%
[] + list(np.arange(10))
# Out:
# [np.int64(0),
#  np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9)]

# %%
oL, Lsq, ImTrP = plaq_states._getPlaqStateOps(0.5, 0.2)
